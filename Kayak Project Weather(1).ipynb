# %% [markdown]
# ## Find GPS Coordinates Using Nominatim

# %%
import requests
import pandas as pd

cities = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %%
gpslist = []
for i in cities:
    gpsrequest = requests.get('https://nominatim.openstreetmap.org/search?format=json&limit=1&q={}'.format(i))
    gpslist.append(gpsrequest.json()[0])

# %%
gpsrequest.json()
# Out:
# [{'place_id': 258418538,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 117858,
#   'boundingbox': ['46.1331664', '46.1908971', '-1.2419231', '-1.111097'],
#   'lat': '46.1591126',
#   'lon': '-1.1520434',
#   'display_name': 'La Rochelle, Charente-Maritime, Nouvelle-Aquitaine, France métropolitaine, 17000, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8014837096874572,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons//poi_boundary_administrative.p.20.png'}]

# %%
dflocs = pd.DataFrame(data = gpslist)

# %%
dflocs['cities'] = cities
dflocs
# Out:
#      place_id                                            licence  osm_type  \
# 0   258697296  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 1   257985771  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 2   257654882  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 3   256418097  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 4   303984676  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 5   256305646  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 6   259023929  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 7   256373580  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 8   258573835  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 9   106552831  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 10  258701048  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# ...

# %%
list = [1,2,3]
dflocs.loc[0, 'feels_like_7davg'] = statistics.mean(list)
dflocs.head()
# Out:
#     place_id                                            licence  osm_type  \
# 0  258697296  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 1  257985771  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 2  257654882  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 3  256418097  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 4  303984676  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
#
#    osm_id                                       boundingbox         lat  \
# 0  376823   [48.6119741, 48.637031, -1.5495487, -1.5094805]  48.6358559
# 1  905534  [48.5979853, 48.6949736, -2.0768518, -1.9367259]  48.6454528
# 2  145776  [49.2608124, 49.2934736, -0.7275671, -0.6757378]  49.2764624
# 3  104492    [49.4516697, 49.5401463, 0.0667992, 0.1955556]  49.4938975
# 4   75628    [49.4172001, 49.4652601, 1.0300648, 1.1521157]  49.4404591
#
#           lon                                       display_name     class  \
# ...

# %% [markdown]
# ## Find Weather Using OWM

# %%
#api key: 7d425d5fe231b347666a4c8e21c3254b

# example api request: api.openweathermap.org/data/2.5/weather?q=London,uk&APPID=7d425d5fe231b347666a4c8e21c3254b
#https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&exclude={part}&appid={API key}
'''
import statistics



for i in dflocs.index:

    lat = dflocs.loc[i, 'lat']
    lon = dflocs.loc[i, 'lon']
    weatherrequest = requests.get('https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&appid=7d425d5fe231b347666a4c8e21c3254b&exclude=current,minutely,hourly,alerts'.format(lat, lon))
    
    collection = []
    for i in range(8):
        collection.append(weatherrequest.json()['daily'][i]['feels_like']['day'])
    dflocs.loc[i, 'feels_like_7davg'] = statistics.mean(collection)
    print(dflocs.loc[i, 'feels_like_7davg'])
    
'''

# %%
#api key: 7d425d5fe231b347666a4c8e21c3254b

# example api request: api.openweathermap.org/data/2.5/weather?q=London,uk&APPID=7d425d5fe231b347666a4c8e21c3254b
#https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&exclude={part}&appid={API key}

import statistics

feels_like_7davg = []

for i in dflocs.index:
    
    lat = dflocs.loc[i, 'lat']
    lon = dflocs.loc[i, 'lon']
    weatherrequest = requests.get('https://api.openweathermap.org/data/2.5/onecall?lat={}&lon={}&appid=7d425d5fe231b347666a4c8e21c3254b&exclude=current,minutely,hourly,alerts'.format(lat, lon))
    
    collection = []
    for i in range(8):
        collection.append(weatherrequest.json()['daily'][i]['feels_like']['day'])
    feels_like_7davg.append(statistics.mean(collection))

# %%
dflocs['feels_like_7davg'] = feels_like_7davg
dflocs.head()
# Out:
#     place_id                                            licence  osm_type  \
# 0  258697296  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 1  257985771  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 2  257654882  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 3  256418097  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 4  303984676  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
#
#    osm_id                                       boundingbox         lat  \
# 0  376823   [48.6119741, 48.637031, -1.5495487, -1.5094805]  48.6358559
# 1  905534  [48.5979853, 48.6949736, -2.0768518, -1.9367259]  48.6454528
# 2  145776  [49.2608124, 49.2934736, -0.7275671, -0.6757378]  49.2764624
# 3  104492    [49.4516697, 49.5401463, 0.0667992, 0.1955556]  49.4938975
# 4   75628    [49.4172001, 49.4652601, 1.0300648, 1.1521157]  49.4404591
#
#           lon                                       display_name     class  \
# ...
